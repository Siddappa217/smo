# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddappa217/smo/blob/main/cie2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/tipssss.csv')
print(df)
df.info()
df.describe()
df.head()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99   NaN  Female     No   Sun  Dinner   2.0              8.49
# 1           NaN  1.66    Male     No   Sun  Dinner   3.0              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner   NaN             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
dff=df.isna().sum()
dff
# Out:
# total_bill          2
# tip                 2
# sex                 0
# smoker              0
# day                 0
# time                0
# size                2
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
new_df=df.fillna(0)
new_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  0.00  Female     No   Sun  Dinner   2.0              8.49
# 1          0.00  1.66    Male     No   Sun  Dinner   3.0              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner   0.0             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
x=df['total_bill']
y=df['tip']
plt.scatter(x,y)
plt.title('scatter of bill and tip')
plt.xlabel('bill')
plt.ylabel('tip')
plt.show()
